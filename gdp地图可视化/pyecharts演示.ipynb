# %%
# 3d柱状图
import random

from pyecharts import options as opts
from pyecharts.charts import Bar3D
from pyecharts.faker import Faker


data = [(i, j, random.randint(0, 12)) for i in range(6) for j in range(24)]
c = (
    Bar3D()
    .add(
        "",
        [[d[1], d[0], d[2]] for d in data],
        xaxis3d_opts=opts.Axis3DOpts(Faker.clock, type_="category"),
        yaxis3d_opts=opts.Axis3DOpts(Faker.week_en, type_="category"),
        zaxis3d_opts=opts.Axis3DOpts(type_="value"),
    )
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_=20),
        title_opts=opts.TitleOpts(title="Bar3D-基本示例"),
    )
#     .render("bar3d_base.html")
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="6bbaf3fb89ca49c3bf46da66a67cacfd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_6bbaf3fb89ca49c3bf46da66a67cacfd = echarts.init(
#                     document.getElementById('6bbaf3fb89ca49c3bf46da66a67cacfd'), 'white', {renderer: 'canvas'});
#                 var option_6bbaf3fb89ca49c3bf46da66a67cacfd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar3D",
#             "data": [
#                 [
#                     0,
#                     0,
#                     2
#                 ],
#                 [
#                     1,
#                     0,
#                     1
#                 ],
#                 [
#                     2,
#                     0,
#                     12
#                 ],
#                 [
#                     3,
#                     0,
#                     12
#                 ],
#                 [
#                     4,
#                     0,
#                     1
#                 ],
#                 [
#                     5,
#                     0,
#                     3
#                 ],
#                 [
#                     6,
#                     0,
#                     6
#                 ],
#                 [
#                     7,
#                     0,
#                     10
#                 ],
#                 [
#                     8,
#                     0,
#                     9
#                 ],
#                 [
#                     9,
#                     0,
#                     1
#                 ],
#                 [
#                     10,
#                     0,
#                     9
#                 ],
#                 [
#                     11,
#                     0,
#                     12
#                 ],
#                 [
#                     12,
#                     0,
#                     5
#                 ],
#                 [
#                     13,
#                     0,
#                     0
#                 ],
#                 [
#                     14,
#                     0,
#                     4
#                 ],
#                 [
#                     15,
#                     0,
#                     5
#                 ],
#                 [
#                     16,
#                     0,
#                     7
#                 ],
#                 [
#                     17,
#                     0,
#                     7
#                 ],
#                 [
#                     18,
#                     0,
#                     2
#                 ],
#                 [
#                     19,
#                     0,
#                     11
#                 ],
#                 [
#                     20,
#                     0,
#                     3
#                 ],
#                 [
#                     21,
#                     0,
#                     6
#                 ],
#                 [
#                     22,
#                     0,
#                     4
#                 ],
#                 [
#                     23,
#                     0,
#                     3
#                 ],
#                 [
#                     0,
#                     1,
#                     7
#                 ],
#                 [
#                     1,
#                     1,
#                     12
#                 ],
#                 [
#                     2,
#                     1,
#                     5
#                 ],
#                 [
#                     3,
#                     1,
#                     9
#                 ],
#                 [
#                     4,
#                     1,
#                     9
#                 ],
#                 [
#                     5,
#                     1,
#                     6
#                 ],
#                 [
#                     6,
#                     1,
#                     0
#                 ],
#                 [
#                     7,
#                     1,
#                     2
#                 ],
#                 [
#                     8,
#                     1,
#                     0
#                 ],
#                 [
#                     9,
#                     1,
#                     12
#                 ],
#                 [
#                     10,
#                     1,
#                     5
#                 ],
#                 [
#                     11,
#                     1,
#                     8
#                 ],
#                 [
#                     12,
#                     1,
#                     1
#                 ],
#                 [
#                     13,
#                     1,
#                     1
#                 ],
#                 [
#                     14,
#                     1,
#                     2
#                 ],
#                 [
#                     15,
#                     1,
#                     4
#                 ],
#                 [
#                     16,
#                     1,
#                     1
#                 ],
#                 [
#                     17,
#                     1,
#                     4
#                 ],
#                 [
#                     18,
#                     1,
#                     5
#                 ],
#                 [
#                     19,
#                     1,
#                     3
#                 ],
#                 [
#                     20,
#                     1,
#                     9
#                 ],
#                 [
#                     21,
#                     1,
#                     0
#                 ],
#                 [
#                     22,
#                     1,
#                     10
#                 ],
#                 [
#                     23,
#                     1,
#                     0
#                 ],
#                 [
#                     0,
#                     2,
#                     8
#                 ],
#                 [
#                     1,
#                     2,
#                     6
#                 ],
#                 [
#                     2,
#                     2,
#                     0
#                 ],
#                 [
#                     3,
#                     2,
#                     11
#                 ],
#                 [
#                     4,
#                     2,
#                     2
#                 ],
#                 [
#                     5,
#                     2,
#                     3
#                 ],
#                 [
#                     6,
#                     2,
#                     11
#                 ],
#                 [
#                     7,
#                     2,
#                     12
#                 ],
#                 [
#                     8,
#                     2,
#                     5
#                 ],
#                 [
#                     9,
#                     2,
#                     9
#                 ],
#                 [
#                     10,
#                     2,
#                     8
#                 ],
#                 [
#                     11,
#                     2,
#                     4
#                 ],
#                 [
#                     12,
#                     2,
#                     12
#                 ],
#                 [
#                     13,
#                     2,
#                     0
#                 ],

# %%
# 广东地图
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker
from pyecharts.globals import ChartType

c = (
    Geo()
    .add_schema(maptype="广东")
    .add(
        "geo",
        [list(z) for z in zip(Faker.guangdong_city, Faker.values())],
        type_=ChartType.HEATMAP,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-广东地图")
    )
#     .render("geo_guangdong.html")
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="cb74746c465f469693f4596d998800cb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_cb74746c465f469693f4596d998800cb = echarts.init(
#                     document.getElementById('cb74746c465f469693f4596d998800cb'), 'white', {renderer: 'canvas'});
#                 var option_cb74746c465f469693f4596d998800cb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": [
#                         116.68,
#                         23.35,
#                         98
#                     ]
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": [
#                         115.37,
#                         22.78,
#                         79
#                     ]
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": [
#                         116.37,
#                         23.55,
#                         99
#                     ]
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": [
#                         111.98,
#                         21.87,
#                         47
#                     ]
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": [
#                         112.47,
#                         23.05,
#                         63
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": [
#                         113.27,
#                         23.13,
#                         103
#                     ]
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": [
#                         114.42,
#                         23.12,
#                         103
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-\u5e7f\u4e1c\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "\u5e7f\u4e1c",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_cb74746c465f469693f4596d998800cb.setOption(option_cb74746c465f469693f4596d998800cb);
#         });
#     </script>

# %%
# 3d地图
from pyecharts import options as opts
from pyecharts.charts import Map3D
from pyecharts.globals import ChartType

c = (
    Map3D()
    .add_schema(
        itemstyle_opts=opts.ItemStyleOpts(
            color="rgb(5,101,123)",
            opacity=1,
            border_width=0.8,
            border_color="rgb(62,215,213)",
        ),
        map3d_label=opts.Map3DLabelOpts(
            is_show=True,
            text_style=opts.TextStyleOpts(
                color="#fff", font_size=16, background_color="rgba(0,0,0,0)"
            ),
        ),
        emphasis_label_opts=opts.LabelOpts(is_show=True),
        light_opts=opts.Map3DLightOpts(
            main_color="#fff",
            main_intensity=1.2,
            is_main_shadow=False,
            main_alpha=55,
            main_beta=10,
            ambient_intensity=0.3,
        ),
    )
    .add(series_name="", data_pair="", maptype=ChartType.MAP3D)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国行政区划地图-Base"),
        visualmap_opts=opts.VisualMapOpts(is_show=False),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
#     .render("map3d_china_base.html")
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="81ef23c5aa25411ea48ac7b63586ea75" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl', 'china'], function(echarts) {
#                 var chart_81ef23c5aa25411ea48ac7b63586ea75 = echarts.init(
#                     document.getElementById('81ef23c5aa25411ea48ac7b63586ea75'), 'white', {renderer: 'canvas'});
#                 var option_81ef23c5aa25411ea48ac7b63586ea75 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map3D",
#             "map": "map3D",
#             "coordinateSystem": "geo3D",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "data": [],
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "visualMap": {
#         "show": false,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo3D": {
#         "map": "china",
#         "boxWidth": 100,
#         "boxHeight": 10,
#         "regionHeight": 3,
#         "groundPlane": {
#             "show": false,
#             "color": "#aaa"
#         },
#         "instancing": false,
#         "itemStyle": {
#             "color": "rgb(5,101,123)",
#             "borderColor": "rgb(62,215,213)",
#             "borderWidth": 0.8,
#             "opacity": 1
#         },
#         "label": {
#             "show": true,
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 16,
#                 "backgroundColor": "rgba(0,0,0,0)"
#             }
#         },
#         "emphasis": {
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         "light": {
#             "main": {
#                 "color": "#fff",
#                 "intensity": 1.2,
#                 "shadow": false,
#                 "shadowQuality": "medium",
#                 "alpha": 55,
#                 "beta": 10
#             },
#             "ambient": {
#                 "color": "#fff",
#                 "intensity": 0.3
#             },
#             "ambientCubemap": {
#                 "diffuseIntensity": 0.5,
#                 "specularIntensity": 0.5
#             }
#         },
#         "temporalSuperSampling": {
#             "enable": "auto"
#         },
#         "zlevel": -10,
#         "left": "auto",
#         "top": "auto",
#         "right": "auto",
#         "bottom": "auto",
#         "width": "auto",
#         "height": "auto"
#     },
#     "title": [
#         {
#             "text": "\u5168\u56fd\u884c\u653f\u533a\u5212\u5730\u56fe-Base",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_81ef23c5aa25411ea48ac7b63586ea75.setOption(option_81ef23c5aa25411ea48ac7b63586ea75);
#         });
#     </script>
